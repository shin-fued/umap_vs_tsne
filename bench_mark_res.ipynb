# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('bench_mark.csv')
df['log tsne_time'] = np.log10(df['tsne_time'])
df['log umap_time'] = np.log10(df['umap_time'])
plt.plot(df['sample_size'], df['tsne_time'], c='r', label='tsne')
plt.plot(df['sample_size'], df['umap_time'], c='g', label='umap')
plt.xlabel('sample size')
plt.ylabel('time s')
plt.ylim(bottom=0,top=10)
plt.title('t-SNE vs UMAP timing')
plt.legend()
plt.show()
